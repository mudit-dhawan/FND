# %%
import os 
import torch
import pandas as pd
import numpy as np
import random 
from torch.utils.data import DataLoader
import torch.nn as nn
import config, dataset, model, engine, utils
from transformers import AdamW, get_linear_schedule_with_warmup

# %%
import torch

print(torch.__version__)
print(torch.version.cuda)
b = torch.nn.Conv2d(32, 32, 2, bias=False, padding=1)
a = torch.randn(2, 32, 0, 5)
print('cpu:', b(a).shape)
b.cuda()
a = a.cuda()
print('cuda:', b(a).shape)
# Out:
# 1.7.1
# 11.0
# cpu: torch.Size([2, 32, 1, 6])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-f8236a798dc2> in <module>()
#       8 b.cuda()
#       9 a = a.cuda()
# ---> 10 print('cuda:', b(a).shape)
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
# --> 423         return self._conv_forward(input, self.weight)
#     424
#     425 class Conv3d(_ConvNd):
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     418                             _pair(0), self.dilation, self.groups)
#     419         return F.conv2d(input, weight, self.bias, self.stride,
# --> 420                         self.padding, self.dilation, self.groups)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: cuDNN error: CUDNN_STATUS_BAD_PARAM

# %%
import torch
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = False
torch.backends.cudnn.allow_tf32 = True
data = torch.randn([6, 3, 224, 224], dtype=torch.float, device='cuda', requires_grad=True)
net = torch.nn.Conv2d(3, 64, kernel_size=[3, 3], padding=[1, 1], stride=[1, 1], dilation=[1, 1], groups=1)
net = net.cuda().float()
out = net(data)
out.backward(torch.randn_like(out))
torch.cuda.synchronize()

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,7"

# %%
# !nvidia-smi
# Out:
# Tue Mar 30 11:44:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    On   | 00000000:1A:00.0 Off |                  N/A |
# | 30%   29C    P8    20W / 350W |      0MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  On   | 00000000:1B:00.0 Off |                  N/A |
# | 42%   67C    P2   107W / 250W |   6791MiB / 11019MiB |     32%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  On   | 00000000:1D:00.0 Off |                  N/A |
# | 40%   64C    P2    93W / 250W |   4297MiB / 11019MiB |     37%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 108...  On   | 00000000:1E:00.0 Off |                  N/A |
# | 28%   24C    P8     9W / 250W |      0MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  On   | 00000000:3D:00.0 Off |                  N/A |
# | 39%   66C    P2   162W / 250W |  10948MiB / 11019MiB |     19%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  On   | 00000000:3F:00.0 Off |                  N/A |
# | 46%   76C    P2   193W / 250W |  10786MiB / 11019MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  On   | 00000000:41:00.0 Off |                  N/A |
# | 42%   67C    P2   119W / 250W |  10302MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 3090    On   | 00000000:86:00.0 Off |                  N/A |
# | 30%   31C    P8    36W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    1   N/A  N/A     22046      C   /usr/bin/python3                 2273MiB |
# |    1   N/A  N/A     40433      C   python                           4515MiB |
# |    2   N/A  N/A     35370      C   .../envs/gector16/bin/python     2069MiB |
# |    2   N/A  N/A     40433      C   python                           2225MiB |
# |    4   N/A  N/A     42342      C   python                          10945MiB |
# |    5   N/A  N/A     12310      C   python                          10783MiB |
# |    6   N/A  N/A     26576      C   python                          10299MiB |
# +-----------------------------------------------------------------------------+

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device name:', torch.cuda.get_device_name(0))

model = models.Multiple_Images_Model()

if torch.cuda.device_count() > 1:
    print("Using", torch.cuda.device_count(), "GPUs")
    model = nn.DataParallel(model)

model.to(device)
# Out:
# Device name: GeForce RTX 3090
# Using 2 GPUs
# DataParallel(
#   (module): Multiple_Images_Model(
#     (text_encoder): Text_Encoder(
#       (base_text_encoder): BertModel(
#         (embeddings): BertEmbeddings(
#           (word_embeddings): Embedding(30522, 768, padding_idx=0)
#           (position_embeddings): Embedding(512, 768)
#           (token_type_embeddings): Embedding(2, 768)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder): BertEncoder(
#           (layer): ModuleList(
#             (0): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (1): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (2): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (3): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (4): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (5): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (6): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (7): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (8): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (9): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (10): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (11): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (pooler): BertPooler(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (activation): Tanh()
#         )
#       )
#       (fc1_text): Sequential(
#         (0): Linear(in_features=768, out_features=512, bias=True)
#         (1): ReLU()
#       )
#       (fc2_text): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): ReLU()
#       )
#       (dropout): Dropout(p=0.4, inplace=False)
#     )
#     (visual_encoder): MultiVisualEncoder(
#       (visual_cnn): VisualCNN(
#         (base_vis_encoder): VGG(
#           (features): Sequential(
#             (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace=True)
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (3): ReLU(inplace=True)
#             (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (6): ReLU(inplace=True)
#             (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (8): ReLU(inplace=True)
#             (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (11): ReLU(inplace=True)
#             (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (13): ReLU(inplace=True)
#             (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (15): ReLU(inplace=True)
#             (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (17): ReLU(inplace=True)
#             (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (20): ReLU(inplace=True)
#             (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (22): ReLU(inplace=True)
#             (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (24): ReLU(inplace=True)
#             (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (26): ReLU(inplace=True)
#             (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (29): ReLU(inplace=True)
#             (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (31): ReLU(inplace=True)
#             (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (33): ReLU(inplace=True)
#             (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (35): ReLU(inplace=True)
#             (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#           (classifier): Sequential(
#             (0): Linear(in_features=25088, out_features=4096, bias=True)
#           )
#         )
#         (fc1_vis): Sequential(
#           (0): Linear(in_features=4096, out_features=1024, bias=True)
#           (1): ReLU()
#         )
#         (dropout): Dropout(p=0.4, inplace=False)
#       )
#       (time_distributed_cnn): TimeDistributed(
#         (module): VisualCNN(
#           (base_vis_encoder): VGG(
#             (features): Sequential(
#               (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#               (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#               (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (6): ReLU(inplace=True)
#               (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (8): ReLU(inplace=True)
#               (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#               (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (11): ReLU(inplace=True)
#               (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (13): ReLU(inplace=True)
#               (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (15): ReLU(inplace=True)
#               (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (17): ReLU(inplace=True)
#               (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#               (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (20): ReLU(inplace=True)
#               (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (22): ReLU(inplace=True)
#               (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (24): ReLU(inplace=True)
#               (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (26): ReLU(inplace=True)
#               (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#               (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (29): ReLU(inplace=True)
#               (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (31): ReLU(inplace=True)
#               (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (33): ReLU(inplace=True)
#               (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (35): ReLU(inplace=True)
#               (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             )
#             (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#             (classifier): Sequential(
#               (0): Linear(in_features=25088, out_features=4096, bias=True)
#             )
#           )
#           (fc1_vis): Sequential(
#             (0): Linear(in_features=4096, out_features=1024, bias=True)
#             (1): ReLU()
#           )
#           (dropout): Dropout(p=0.4, inplace=False)
#         )
#       )
#       (visual_rnn): LSTM(1024, 512, batch_first=True, bidirectional=True)
#       (fc2_vis): Sequential(
#         (0): Linear(in_features=1024, out_features=256, bias=True)
#         (1): ReLU()
#       )
#       (dropout): Dropout(p=0.4, inplace=False)
#     )
#     (sim_module): SimilarityModule(
#       (vis_latent_space): Linear(in_features=1024, out_features=128, bias=True)
#       (vis_latent_vec): TimeDistributed(
#         (module): Linear(in_features=1024, out_features=128, bias=True)
#       )
#       (text_latent_vec): Linear(in_features=512, out_features=128, bias=True)
#     )
#     (fc3_vis): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#     )
#     (fc3_text): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#     )
#     (fc_multimodal): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#     )
#     (fc_l2): Linear(in_features=128, out_features=2, bias=True)
#     (fc_l3): Linear(in_features=128, out_features=2, bias=True)
#     (fc_l4): Linear(in_features=128, out_features=2, bias=True)
#     (dropout): Dropout(p=0.4, inplace=False)
#   )
# )

# %%
# !nvidia-smi
# Out:
# Tue Mar 30 11:45:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    On   | 00000000:1A:00.0 Off |                  N/A |
# | 30%   31C    P2   102W / 350W |   2413MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  On   | 00000000:1B:00.0 Off |                  N/A |
# | 42%   69C    P2   113W / 250W |   6791MiB / 11019MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  On   | 00000000:1D:00.0 Off |                  N/A |
# | 39%   66C    P2   107W / 250W |   4297MiB / 11019MiB |     38%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 108...  On   | 00000000:1E:00.0 Off |                  N/A |
# | 28%   24C    P8     9W / 250W |      0MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  On   | 00000000:3D:00.0 Off |                  N/A |
# | 39%   62C    P2    79W / 250W |  10948MiB / 11019MiB |     46%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  On   | 00000000:3F:00.0 Off |                  N/A |
# | 46%   75C    P2   223W / 250W |  10786MiB / 11019MiB |     61%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  On   | 00000000:41:00.0 Off |                  N/A |
# | 43%   68C    P2   106W / 250W |  10302MiB / 11019MiB |     19%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 3090    On   | 00000000:86:00.0 Off |                  N/A |
# | 30%   31C    P8    36W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     19414      C   .../envs/fakenews/bin/python     2411MiB |
# |    1   N/A  N/A     22046      C   /usr/bin/python3                 2273MiB |
# |    1   N/A  N/A     40433      C   python                           4515MiB |
# |    2   N/A  N/A     35370      C   .../envs/gector16/bin/python     2069MiB |
# |    2   N/A  N/A     40433      C   python                           2225MiB |
# |    4   N/A  N/A     42342      C   python                          10945MiB |
# |    5   N/A  N/A     12310      C   python                          10783MiB |
# |    6   N/A  N/A     26576      C   python                          10299MiB |
# +-----------------------------------------------------------------------------+

# %%
df_train, df_test = utils.split_data()
train_dataset = dataset.FakeNewsDataset(df_train)
train_data_loader = DataLoader(train_dataset, batch_size=config.TRAIN_BATCH_SIZE,
                        shuffle=True)

val_dataset = dataset.FakeNewsDataset(df_test)
val_data_loader = DataLoader(val_dataset, batch_size=config.EVAL_BATCH_SIZE,
                        shuffle=True)
print("Dataset Loaded")
# Out:
# Dataset Loaded

# %%
optimizer = AdamW(model.parameters(), lr=config.LR)

# Total number of training steps
num_train_steps = len(train_data_loader) *config.EPOCHS

scheduler = get_linear_schedule_with_warmup(
    optimizer, num_warmup_steps=0, num_training_steps=num_train_steps
)

# %%
best_loss = np.inf
for epoch in range(config.EPOCHS):
    train_loss = engine.train_func_epoch(epoch, model, train_data_loader, device, optimizer, scheduler)
    val_loss, acc, prec, rec, f1_score = engine.eval_func(model, val_data_loader, device, epoch)

    if (val_loss < best_loss) and (config.SAVE_MODEL == True):
        torch.save(model.state_dict(), config.MODEL_PATH)
        best_loss = val_loss
# Out:
# Training- Epoch 0:   0%|          | 0/1024 [00:00<?, ?batch/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-04f49d24dfe7> in <module>()
#       1 best_loss = np.inf
#       2 for epoch in range(config.EPOCHS):
# ----> 3     train_loss = engine.train_func_epoch(epoch, model, train_data_loader, device, optimizer, scheduler)
#       4     val_loss, acc, prec, rec, f1_score = engine.eval_func(model, val_data_loader, device, epoch)
#       5
#
# /media/data_dump/Shivangi/Mudit/code/src/engine.py in train_func_epoch(epoch, model, data_loader, device, optimizer, scheduler)
#      30
#      31             # Perform a forward pass. This will return Multimodal vec and total loss.
# ---> 32             sim_vec, logits_l2, logits_l3, logits_l4 = model(text=[input_ids, attn_mask], image=img_ip, label=label)
#      33
#      34             loss = utils.final_loss(sim_vec, logits_l2, logits_l3, logits_l4, label)
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     155                                    "them on device: {}".format(self.src_device_obj, t.device))
#     156
# --> 157         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#     158         if len(self.device_ids) == 1:
#     159             return self.module(*inputs[0], **kwargs[0])
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in scatter(self, inputs, kwargs, device_ids)
#     166
#     167     def scatter(self, inputs, kwargs, device_ids):
# --> 168         return scatter_kwargs(inputs, kwargs, device_ids, dim=self.dim)
#     169
#     170     def parallel_apply(self, replicas, inputs, kwargs):
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/scatter_gather.py in scatter_kwargs(inputs, kwargs, target_gpus, dim)
#      35     r"""Scatter with support for kwargs dictionary"""
#      36     inputs = scatter(inputs, target_gpus, dim) if inputs else []
# ---> 37     kwargs = scatter(kwargs, target_gpus, dim) if kwargs else []
#      38     if len(inputs) < len(kwargs):
#      39         inputs.extend([() for _ in range(len(kwargs) - len(inputs))])
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/scatter_gather.py in scatter(inputs, target_gpus, dim)
#      26     # None, clearing the cell
#      27     try:
# ---> 28         res = scatter_map(inputs)
#      29     finally:
#      30         scatter_map = None
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/scatter_gather.py in scatter_map(obj)
#      17             return list(map(list, zip(*map(scatter_map, obj))))
#      18         if isinstance(obj, dict) and len(obj) > 0:
# ---> 19             return list(map(type(obj), zip(*map(scatter_map, obj.items()))))
#      20         return [obj for targets in target_gpus]
#      21
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/scatter_gather.py in scatter_map(obj)
#      13             return Scatter.apply(target_gpus, None, dim, obj)
#      14         if isinstance(obj, tuple) and len(obj) > 0:
# ---> 15             return list(zip(*map(scatter_map, obj)))
#      16         if isinstance(obj, list) and len(obj) > 0:
#      17             return list(map(list, zip(*map(scatter_map, obj))))
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/scatter_gather.py in scatter_map(obj)
#      15             return list(zip(*map(scatter_map, obj)))
#      16         if isinstance(obj, list) and len(obj) > 0:
# ---> 17             return list(map(list, zip(*map(scatter_map, obj))))
#      18         if isinstance(obj, dict) and len(obj) > 0:
#      19             return list(map(type(obj), zip(*map(scatter_map, obj.items()))))
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/scatter_gather.py in scatter_map(obj)
#      11     def scatter_map(obj):
#      12         if isinstance(obj, torch.Tensor):
# ---> 13             return Scatter.apply(target_gpus, None, dim, obj)
#      14         if isinstance(obj, tuple) and len(obj) > 0:
#      15             return list(zip(*map(scatter_map, obj)))
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/_functions.py in forward(ctx, target_gpus, chunk_sizes, dim, input)
#      90             # Perform CPU to GPU copies in a background stream
#      91             streams = [_get_stream(device) for device in target_gpus]
# ---> 92         outputs = comm.scatter(input, target_gpus, chunk_sizes, ctx.dim, streams)
#      93         # Synchronize with the copy stream
#      94         if streams is not None:
#
# /home/shivangi/.conda/envs/fakenews/lib/python3.7/site-packages/torch/nn/parallel/comm.py in scatter(tensor, devices, chunk_sizes, dim, streams, out)
#     184     if out is None:
#     185         devices = [_get_device_index(d) for d in devices]
# --> 186         return tuple(torch._C._scatter(tensor, devices, chunk_sizes, dim, streams))
#     187     else:
#     188         if devices is not None:
#
# RuntimeError: CUDA error: out of memory
